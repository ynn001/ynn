# %% [markdown]
# # 金融科技第一次实验 Fintech WorkShop No.1
#
# ## 实验目标：熟悉Git、GitHub、Markdown和Jupyter
#
# ## 实验内容
#
# *   git [官方网站](https://git-scm.com/doc)
# *   GitHub [官方网站](https://www.github.com)
# *   Markdown [CheatSheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
# *   Jupyter Notebook [CheatSheet](https://res.cloudinary.com/dyd911kmh/image/upload/v1676302533/Marketing/Blog/Jupyterlab_Cheat_Sheet.pdf)
#
# ### 1\. GIT和Github
#
# 因为我们一直在不断进步，所以我们也不断修改我们的文档和代码。：）
# GIT能够帮助我们更好地进行版本管理。 “版本控制”，也称为版本控制，源代码控制 或软件配置管理（SCM），是 **存储和管理文档、代码的更改信息。**
#
# 跟踪并重现工作的每一步 在软件世界中：它被称为版本控制！
#
# （优秀的）版本控制工具给你带来了什么？
#
# 安心（备份） 自由（探索性分支） 协作（同步）
#
# #### GIT常用命令和用法
#
# *   **安装git** 参见官网安装文档 [link](https://git-scm.com/book/zh/v2/%E8%B5%B7%E6%AD%A5-%E5%AE%89%E8%A3%85-Git)
#
# *   **在本地创建存储库repo** （_请补齐操作步骤_）
#
#     1.  设置git全局用户名
#     2.  初始化当前文件夹为git仓库
#     3.  设置git当前仓库用户名
#     4.  检查当前用户名设置
# *   **在本地创建文件、添加文件和修改文件时的git操作** （_请补齐操作步骤_）
#
#     1.  创建本文档workshop.ipynb
#     2.  添加和确认提交此文件
#     3.  修改文件后再次确认提交
#     4.  查看当前仓库状态
# *   **创建远程仓库[ref](https://docs.github.com/zh/get-started/importing-your-projects-to-github/importing-source-code-to-github/adding-locally-hosted-code-to-github)** （_请补齐操作步骤_）
#
#     1.  在github上创建账号并获取ssh-key
#     2.  在github上创建一个没有readme、许可协议和git ignore文件的新存储库
#     3.  在上一步创建的本地仓库中添加远程仓库地址（github）
#     4.  将本地仓库的更改推送到github中
# *   **获取他人（组长）的远程仓库到本地并完成更改后提交** （_请补齐操作步骤_）
#
# *   **组长合并他人的提交** （_请补齐操作步骤_）
#
#
# ### 2\. Markdown常用命令和用法
# #### 常用语法
#
# （_请补齐命令和说明_）
#
# *   标题 （这是xxx的自我介绍标题）
# *   粗体、斜体和~删除线~ （我的**兴趣爱好**， 我的_擅长_， 我改进了~哪些我不喜欢的内容~）
# *   有序列表和无序列表
# *   [超链接](https://www.swufe.edu.cn)
# *   插入图像
# *   插入`代码`以突出显示
# *   插入整块引用
#
#     > 这是我最近最喜欢的一句话，是由某某某所讲
#
# *   插入视频
#
# <iframe src="//player.bilibili.com/player.html?aid=327623069&bvid=BV1JA411h7Gw&cid=171385214&page=1" scrolling="no" border="0" frameborder="no" framespacing="0" allowfullscreen="true"> </iframe>
#
#
# * * *
#
# #### 完成个人介绍，使用Markdown完成
#
# * * *
#
# #### 请各自补充组员的基本信息
#
# | 姓名 | 学号 | 专业及年级 | 小组代号 |
# | --- | --- | --- | --- |
# | 尹妞妞 | 42104004 | 2021信用管理 | ABCD |
# | bbb | 41000000 | 2021信用管理 |ABCD  |
# | bbb | 41000000 | 2021信用管理 |ABCD  |
# | bbb | 41000000 | 2021信用管理 |ABCD  |
# | bbb | 41000000 | 2021信用管理 | ABCD  |
# | bbb | 41000000 | 2021信用管理 | ABCD  |
#
# #### Latex（选）<https://editor.codecogs.com/>
#
# -   二次项定理
#
# \$\$ (x+y)\^n = \\sum\_{k=0}\^n {n \\choose k} x\^{n - k} y\^k. \$\$
#
# -   指数函数
#
# \$\$ e\^x = \\lim\_{n \\to \\infty} \\left( 1+ \\frac{x}{n} \\right)\^n.
# \$\$
#
# -   柯西不等式
#
# \$\$ \\left( \\sum\_{k=1}\^n a_k b_k \\right)\^2 \\leq \\left(
# \\sum\_{k=1}\^n a_k\^2 \\right) \\left( \\sum\_{k=1}\^n b_k\^2 \\right).
# \$\$
#
# -   贝叶斯定理
#
# \$\$ P(A \\mid B) = \\frac{P(B \\mid A) \\, P(A)}{P(B)}. \$\$
#
# -   欧拉公式
#
# **Theorem** (Euler's summation formula). If $ f  $has a continuous derivative $ f' $ on the interval$ [y, x], $ where $ 0 < y < x, $ then\begin{align} \sum_{y < n \le x} f(n) = & \int_y^x f(t) \, dt + \int_y^x (t - [t]) f'(t) \, dt \notag \\ & + f(x)([x] - x) - f(y)([y] - y). \label{theorem}\end{align}
# Proof. Let $ m = [y] $ and $ k = [x]. $ Forintegers $ n $ and $ n - 1 $ in $ [y, x] $ we have\begin{align*} \int_{n - 1}^n [t] f'(t) \, dt & = \int_{n - 1}^n (n - 1) f'(t) \, dt \\ & = (n - 1) \{ f(n) - f(n - 1) \} \\ & = \{n f(n) - (n - 1) f(n - 1)\} - f(n).\end{align*}Summing from $ n = m + 2 $ to $ n = k $ we findthat the first sum telescopes, hence\begin{align*} \int_{m + 1}^k [t] f'(t) \, dt & = k f(k) - (m + 1) f(m + 1) - \sum_{n = m + 2}^k f(n) \\ & = k f(k) - m f(m + 1) - \sum_{y < n \le x} f(n).\end{align*}Therefore\begin{align} \sum_{y < n \le x} f(n) & = - \int_{m + 1}^k [t] f'(t) \, dt + k f(k) - m f(m + 1) \notag \\ & = - \int_y^x [t] f'(t) \, dt + k f(x) - m f(y). \label{summation}\end{align}Integration by parts gives us$$\int_y^x f(t) \, dt = x f(x) - y f(y) - \int_y^x t f'(t) \, dt,$$
#
# ### 3.Jupyter的基本用法

# %%
# !python -V
# Out:
# Python 3.7.6
